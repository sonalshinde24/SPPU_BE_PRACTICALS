# %% [markdown]
# # Load Balancing Algorithms Simulation
#
# This notebook demonstrates:
# - Round Robin Load Balancing
# - Random Allocation
# - Least Connections Method

# %%
import random

# Simulated servers
servers = {
    "Server1": 0,
    "Server2": 0,
    "Server3": 0
}

# Simulated client requests
requests = ["Req1", "Req2", "Req3", "Req4", "Req5", "Req6"]

print("Client Requests:", requests)
# Out:
# Client Requests: ['Req1', 'Req2', 'Req3', 'Req4', 'Req5', 'Req6']

# %%
print("\n--- Round Robin ---")

rr_servers = list(servers.keys())
rr_index = 0

for req in requests:
    server = rr_servers[rr_index]
    print(f"{req} -> {server}")
    rr_index = (rr_index + 1) % len(rr_servers)
# Out:
# --- Round Robin ---
# Req1 -> Server1
# Req2 -> Server2
# Req3 -> Server3
# Req4 -> Server1
# Req5 -> Server2
# Req6 -> Server3

# %%
print("\n--- Random Allocation ---")

for req in requests:
    server = random.choice(list(servers.keys()))
    print(f"{req} -> {server}")
# Out:
# --- Random Allocation ---
# Req1 -> Server3
# Req2 -> Server1
# Req3 -> Server1
# Req4 -> Server3
# Req5 -> Server2
# Req6 -> Server2

# %%
print("\n--- Least Connections ---")

# Reset loads
server_load = {s: 0 for s in servers}

for req in requests:
    # Find server with minimum load
    server = min(server_load, key=server_load.get)
    
    print(f"{req} -> {server}")
    
    # Increase load
    server_load[server] += 1

print("\nFinal Server Loads:", server_load)
# Out:
# --- Least Connections ---
# Req1 -> Server1
# Req2 -> Server2
# Req3 -> Server3
# Req4 -> Server1
# Req5 -> Server2
# Req6 -> Server3
#
# Final Server Loads: {'Server1': 2, 'Server2': 2, 'Server3': 2}

# %% [markdown]
# ## Explanation
#
# ### 1. Round Robin
# Each request is assigned sequentially to servers.
#
# ### 2. Random Allocation
# Requests are assigned randomly to any server.
#
# ### 3. Least Connections
# Requests are assigned to the server with the lowest current load.
#
# This method is more efficient in real-world systems.
