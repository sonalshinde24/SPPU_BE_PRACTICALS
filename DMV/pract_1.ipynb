# %% [markdown]
# # Title : Analyzing Sales Data from Multiple File Formats

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
""" 
1. Load the sales data from each file format into the appropriate data structures or
dataframes.
"""

csv = pd.read_csv('sales_data_sample.csv', encoding='cp1252')
csv.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
excel = pd.read_excel('sales2.xlsx')
excel.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10154               30      95.70                2  2871.00
# 1        10155               34      81.35                5  2765.90
# 2        10156               41      94.74                2  3884.34
# 3        10157               45      83.26                6  3746.70
# 4        10158               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       EMEA              Yu             Paul   Medium
# 1      51100  France       EMEA         Henriot             Paul    Small
# 2      75508  France        NaN        Da Cunha           Daniel   Medium
# 3      90003     USA        NaN           Young            Julie   Medium
# 4        NaN     USA        NaN           Brown             suvi   Medium
#
# [5 rows x 25 columns]

# %%
json = pd.read_json(r'sales1.json')
json.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10184               30      95.70                2  2871.00
# 1        10185               34      81.35                5  2765.90
# 2        10186               41      94.74                2  3884.34
# 3        10187               45      83.26                6  3746.70
# 4        10188               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# 1             59 rue de l'Abbaye                        Reims
# 2  27 rue du Colonel Pierre Avia                        Paris
# 3             78934 Hillside Dr.                     Pasadena    CA
# 4                7734 Strong St.                San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA      EMEA              Yu             Paul   Medium
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France        NA        Da Cunha           Daniel   Medium
# 3      90003     USA        NA           Young            Julie   Medium
# 4                USA        NA           Brown             suvi   Medium
#
# [5 rows x 25 columns]

# %%
""" 
2. Explore the structure and content of the loaded data, identifying any inconsistencies,
missing values, or data quality issues.
3. Perform data cleaning operations, such as handling missing values, removing
duplicates, or correcting inconsistencies.
"""
# Out:
# ' \n2. Explore the structure and content of the loaded data, identifying any inconsistencies,\nmissing values, or data quality issues.\n3. Perform data cleaning operations, such as handling missing values, removing\nduplicates, or correcting inconsistencies.\n'

# %% [markdown]
# # Data Cleaning For CSV

# %%
csv.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
csv.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
csv['ADDRESSLINE2'] = csv['ADDRESSLINE2'].fillna('Not Available')
csv = csv.drop(columns=['STATE'])
csv['TERRITORY'] = csv['TERRITORY'].fillna('Unknown')
csv = csv.drop(columns=['POSTALCODE'])
csv.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
csv.duplicated().sum()
# Out:
# 0

# %%
csv.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# 25%     2203.430000     2.000000     4.000000  2003.00000    68.000000
# 50%     3184.800000     3.000000     8.000000  2004.00000    99.000000
# 75%     4508.000000     4.000000    11.000000  2004.00000   124.000000
# max    14082.800000     4.000000    12.000000  2005.00000   214.000000

# %%
csv.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1        Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2           Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3         Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Corporate Gift Ideas Co.        6505551386                7734 Strong St.
#
#     ADDRESSLINE2           CITY COUNTRY TERRITORY CONTACTLASTNAME  \
# 0  Not Available            NYC     USA   Unknown              Yu
# 1  Not Available          Reims  France      EMEA         Henriot
# 2  Not Available          Paris  France      EMEA        Da Cunha
# 3  Not Available       Pasadena     USA   Unknown           Young
# 4  Not Available  San Francisco     USA   Unknown           Brown
#
#   CONTACTFIRSTNAME DEALSIZE
# 0             Kwai    Small
# 1             Paul    Small
# 2           Daniel   Medium
# 3            Julie   Medium
# 4            Julie   Medium
#
# [5 rows x 23 columns]

# %%
csv.shape
# Out:
# (2823, 23)

# %%
csv['ORDERNUMBER'].nunique()
# Out:
# 307

# %%
plt.figure(figsize=(5,4))
sns.boxplot(y=csv['SALES'])   # Replace with your column
plt.title("SALES DATA")
plt.show()

# %%
csv.shape
# Out:
# (2823, 23)

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower) & (df[column] <= upper)]
    return df

# Example use
csv = remove_outliers(csv, 'SALES')
print("After removing outliers:", csv.shape)
# Out:
# After removing outliers: (2742, 23)

# %%
plt.figure(figsize=(5,4))
sns.boxplot(y=csv['SALES'])   # Replace with your column
plt.title("SALES DATA")
plt.show()

# %%
csv.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2742.000000      2742.000000  2742.000000      2742.000000
# mean   10258.067104        34.687454    83.178260         6.497812
# std       91.662137         9.426014    20.272402         4.231770
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.080000         3.000000
# 50%    10262.000000        34.000000    94.140000         6.000000
# 75%    10332.000000        42.000000   100.000000         9.000000
# max    10425.000000        85.000000   100.000000        18.000000
#
#              SALES       QTR_ID     MONTH_ID      YEAR_ID         MSRP
# count  2742.000000  2742.000000  2742.000000  2742.000000  2742.000000
# mean   3387.921433     2.722101     7.108315  2003.809263    98.943472
# std    1576.715785     1.205944     3.661868     0.695859    38.583304
# min     482.130000     1.000000     1.000000  2003.000000    33.000000
# 25%    2173.805000     2.000000     4.000000  2003.000000    68.000000
# 50%    3141.585000     3.000000     8.000000  2004.000000    97.000000
# 75%    4351.212500     4.000000    11.000000  2004.000000   122.000000
# max    7962.240000     4.000000    12.000000  2005.000000   214.000000

# %% [markdown]
# # Data Cleaning For excel

# %%
excel.isnull().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# ADDRESSLINE2        10
# CITY                 0
# STATE                5
# POSTALCODE           2
# COUNTRY              0
# TERRITORY            5
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
excel.duplicated().sum()
# Out:
# 0

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       10 non-null     int64
#  1   QUANTITYORDERED   10 non-null     int64
#  2   PRICEEACH         10 non-null     float64
#  3   ORDERLINENUMBER   10 non-null     int64
#  4   SALES             10 non-null     float64
#  5   ORDERDATE         10 non-null     datetime64[ns]
#  6   STATUS            10 non-null     object
#  7   QTR_ID            10 non-null     int64
#  8   MONTH_ID          10 non-null     int64
#  9   YEAR_ID           10 non-null     int64
#  10  PRODUCTLINE       10 non-null     object
#  11  MSRP              10 non-null     int64
#  12  PRODUCTCODE       10 non-null     object
#  13  CUSTOMERNAME      10 non-null     object
#  14  PHONE             10 non-null     object
#  15  ADDRESSLINE1      10 non-null     object
#  16  ADDRESSLINE2      0 non-null      float64
#  17  CITY              10 non-null     object
#  18  STATE             5 non-null      object
#  19  POSTALCODE        8 non-null      object
#  20  COUNTRY           10 non-null     object
#  21  TERRITORY         5 non-null      object
#  22  CONTACTLASTNAME   10 non-null     object
#  23  CONTACTFIRSTNAME  10 non-null     object
#  24  DEALSIZE          10 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(7), object(14)
# memory usage: 2.1+ KB

# %%
excel.describe()
# Out:
#        ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER        SALES  \
# count     10.00000        10.000000   10.000000        10.000000    10.000000
# mean   10158.50000        37.500000   93.641000         5.600000  3684.004000
# min    10154.00000        22.000000   81.350000         1.000000  2168.540000
# 25%    10156.25000        31.000000   88.282500         2.000000  2792.175000
# 50%    10158.50000        38.500000   96.180000         3.500000  3613.230000
# 75%    10160.75000        44.000000   99.642500         8.250000  4502.415000
# max    10163.00000        49.000000  100.000000        14.000000  5512.320000
# std        3.02765         8.860023    7.268014         5.103376  1154.696322
#
#                  ORDERDATE     QTR_ID  MONTH_ID      YEAR_ID  MSRP  \
# count                   10  10.000000  10.00000    10.000000  10.0
# mean   2003-09-10 16:48:00   3.000000   7.70000  2003.100000  95.0
# min    2003-02-24 00:00:00   1.000000   1.00000  2003.000000  95.0
# 25%    2003-07-14 18:00:00   2.250000   5.50000  2003.000000  95.0
# 50%    2003-10-19 00:00:00   3.500000   9.00000  2003.000000  95.0
# 75%    2003-11-16 06:00:00   4.000000  10.75000  2003.000000  95.0
# max    2004-01-15 00:00:00   4.000000  12.00000  2004.000000  95.0
# std                    NaN   1.247219   3.88873     0.316228   0.0
#
#        ADDRESSLINE2
# count           0.0
# mean            NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
# std             NaN

# %%
excel.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10154               30      95.70                2  2871.00
# 1        10155               34      81.35                5  2765.90
# 2        10156               41      94.74                2  3884.34
# 3        10157               45      83.26                6  3746.70
# 4        10158               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY  TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       EMEA              Yu             Paul   Medium
# 1      51100  France       EMEA         Henriot             Paul    Small
# 2      75508  France        NaN        Da Cunha           Daniel   Medium
# 3      90003     USA        NaN           Young            Julie   Medium
# 4        NaN     USA        NaN           Brown             suvi   Medium
#
# [5 rows x 25 columns]

# %% [markdown]
# # Data Cleaning For Json

# %%
json.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10184               30      95.70                2  2871.00
# 1        10185               34      81.35                5  2765.90
# 2        10186               41      94.74                2  3884.34
# 3        10187               45      83.26                6  3746.70
# 4        10188               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# 1             59 rue de l'Abbaye                        Reims
# 2  27 rue du Colonel Pierre Avia                        Paris
# 3             78934 Hillside Dr.                     Pasadena    CA
# 4                7734 Strong St.                San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA      EMEA              Yu             Paul   Medium
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France        NA        Da Cunha           Daniel   Medium
# 3      90003     USA        NA           Young            Julie   Medium
# 4                USA        NA           Brown             suvi   Medium
#
# [5 rows x 25 columns]

# %%
json.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       10 non-null     int64
#  1   QUANTITYORDERED   10 non-null     int64
#  2   PRICEEACH         10 non-null     float64
#  3   ORDERLINENUMBER   10 non-null     int64
#  4   SALES             10 non-null     float64
#  5   ORDERDATE         10 non-null     object
#  6   STATUS            10 non-null     object
#  7   QTR_ID            10 non-null     int64
#  8   MONTH_ID          10 non-null     int64
#  9   YEAR_ID           10 non-null     int64
#  10  PRODUCTLINE       10 non-null     object
#  11  MSRP              10 non-null     int64
#  12  PRODUCTCODE       10 non-null     object
#  13  CUSTOMERNAME      10 non-null     object
#  14  PHONE             10 non-null     object
#  15  ADDRESSLINE1      10 non-null     object
#  16  ADDRESSLINE2      10 non-null     object
#  17  CITY              10 non-null     object
#  18  STATE             10 non-null     object
#  19  POSTALCODE        10 non-null     object
#  20  COUNTRY           10 non-null     object
#  21  TERRITORY         10 non-null     object
#  22  CONTACTLASTNAME   10 non-null     object
#  23  CONTACTFIRSTNAME  10 non-null     object
#  24  DEALSIZE          10 non-null     object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 2.1+ KB

# %%
json.describe()
# Out:
#        ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER        SALES  \
# count     10.00000        10.000000   10.000000        10.000000    10.000000
# mean   10188.50000        37.500000   93.641000         5.600000  3684.004000
# std        3.02765         8.860023    7.268014         5.103376  1154.696322
# min    10184.00000        22.000000   81.350000         1.000000  2168.540000
# 25%    10186.25000        31.000000   88.282500         2.000000  2792.175000
# 50%    10188.50000        38.500000   96.180000         3.500000  3613.230000
# 75%    10190.75000        44.000000   99.642500         8.250000  4502.415000
# max    10193.00000        49.000000  100.000000        14.000000  5512.320000
#
#           QTR_ID  MONTH_ID      YEAR_ID  MSRP
# count  10.000000  10.00000    10.000000  10.0
# mean    3.000000   7.70000  2003.100000  95.0
# std     1.247219   3.88873     0.316228   0.0
# min     1.000000   1.00000  2003.000000  95.0
# 25%     2.250000   5.50000  2003.000000  95.0
# 50%     3.500000   9.00000  2003.000000  95.0
# 75%     4.000000  10.75000  2003.000000  95.0
# max     4.000000  12.00000  2004.000000  95.0

# %%
json.describe(include=object)
# Out:
#              ORDERDATE   STATUS  PRODUCTLINE PRODUCTCODE       CUSTOMERNAME  \
# count               10       10           10          10                 10
# unique              10        1            1           1                 10
# top     2/24/2003 0:00  Shipped  Motorcycles    S10_1678  Land of Toys Inc.
# freq                 1       10           10          10                  1
#
#              PHONE             ADDRESSLINE1 ADDRESSLINE2   CITY STATE  \
# count           10                       10           10     10    10
# unique          10                       10            1      8     3
# top     2125557818  897 Long Airport Avenue               Paris
# freq             1                        1           10      2     5
#
#        POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# count          10      10        10              10               10       10
# unique          9       3         2              10                7        2
# top                   USA      EMEA              Yu            Julie   Medium
# freq            2       5         5               1                3        7

# %%
json.duplicated().sum()
# Out:
# 0

# %%
# 4. Convert the data into a unified format, such as a common dataframe or data structure,
# to enable seamless analysis.
unified_data = pd.concat([csv, excel, json], axis=0, ignore_index=True)

# %%
unified_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1   ADDRESSLINE2           CITY COUNTRY  \
# 0        897 Long Airport Avenue  Not Available            NYC     USA
# 1             59 rue de l'Abbaye  Not Available          Reims  France
# 2  27 rue du Colonel Pierre Avia  Not Available          Paris  France
# 3             78934 Hillside Dr.  Not Available       Pasadena     USA
# 4                7734 Strong St.  Not Available  San Francisco     USA
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE STATE POSTALCODE
# 0   Unknown              Yu             Kwai    Small   NaN        NaN
# 1      EMEA         Henriot             Paul    Small   NaN        NaN
# 2      EMEA        Da Cunha           Daniel   Medium   NaN        NaN
# 3   Unknown           Young            Julie   Medium   NaN        NaN
# 4   Unknown           Brown            Julie   Medium   NaN        NaN
#
# [5 rows x 25 columns]

# %%
unified_data.shape
# Out:
# (2762, 25)

# %%
csv.shape, excel.shape, json.shape
# Out:
# ((2742, 23), (10, 25), (10, 25))

# %%
unified_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2762 entries, 0 to 2761
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2762 non-null   int64
#  1   QUANTITYORDERED   2762 non-null   int64
#  2   PRICEEACH         2762 non-null   float64
#  3   ORDERLINENUMBER   2762 non-null   int64
#  4   SALES             2762 non-null   float64
#  5   ORDERDATE         2762 non-null   object
#  6   STATUS            2762 non-null   object
#  7   QTR_ID            2762 non-null   int64
#  8   MONTH_ID          2762 non-null   int64
#  9   YEAR_ID           2762 non-null   int64
#  10  PRODUCTLINE       2762 non-null   object
#  11  MSRP              2762 non-null   int64
#  12  PRODUCTCODE       2762 non-null   object
#  13  CUSTOMERNAME      2762 non-null   object
#  14  PHONE             2762 non-null   object
#  15  ADDRESSLINE1      2762 non-null   object
#  16  ADDRESSLINE2      2752 non-null   object
#  17  CITY              2762 non-null   object
#  18  COUNTRY           2762 non-null   object
#  19  TERRITORY         2757 non-null   object
#  20  CONTACTLASTNAME   2762 non-null   object
#  21  CONTACTFIRSTNAME  2762 non-null   object
#  22  DEALSIZE          2762 non-null   object
#  23  STATE             15 non-null     object
#  24  POSTALCODE        18 non-null     object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 539.6+ KB

# %%
# 5. Perform data transformation tasks, such as merging multiple datasets, splitting
# columns, or deriving new variables.

unified_data.duplicated().sum()
# Out:
# 0

# %%
total_sales = unified_data['SALES'].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 9363360.649999999

# %%
category_sales = unified_data.groupby('PRODUCTLINE')['SALES'].mean()

# %%
# Plot mean sales per order
category_sales.plot(kind='bar', figsize=(12,7))

plt.title("Total Sales By Product Line")
plt.xlabel("Order Number")
plt.ylabel("Average Sales")
plt.show()

# %%
"""
6. Analyze the sales data by performing descriptive statistics, aggregating data by
specific variables, or calculating metrics such as total sales, average order value, or
product category distribution.
7. Create visualizations, such as bar plots, pie charts, or box plots, to represent the sales
data and gain insights into sales trends, customer behavior, or product performance.
"""
# Out:
# '\n6. Analyze the sales data by performing descriptive statistics, aggregating data by\nspecific variables, or calculating metrics such as total sales, average order value, or\nproduct category distribution.\n7. Create visualizations, such as bar plots, pie charts, or box plots, to represent the sales\ndata and gain insights into sales trends, customer behavior, or product performance.\n'

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="PRODUCTLINE", y="SALES", data=unified_data, estimator=sum)
plt.title("Total Sales by Product Line")
plt.xticks(rotation=55)
plt.show()

# %%
# Sales Distribution by Country (Top 10 countries) - Bar Plot

top_countries = unified_data.groupby("COUNTRY")["SALES"].sum().nlargest(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title("Top 10 Countries by Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Deal Size Distribution (Pie Chart)

plt.figure(figsize=(6,6))
unified_data["DEALSIZE"].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Deal Size Distribution")
plt.ylabel("")  # remove y-label
plt.show()

# %%
#  Sales by Year (Bar Plot)

plt.figure(figsize=(8,5))
sns.barplot(x="YEAR_ID", y="SALES", data=unified_data, estimator=sum)
plt.title("Total Sales by Year")
plt.show()

# %%
# Sales Distribution (Box Plot)
plt.figure(figsize=(8,5))
sns.boxplot(x="DEALSIZE", y="SALES", data=unified_data)
plt.title("Sales Distribution by Deal Size")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="DEALSIZE", y="SALES", data=unified_data)
plt.title("Sales Distribution by Deal Size")
plt.show()
